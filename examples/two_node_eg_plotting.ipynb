# %%
simtwo_data = [14.719998381, 25.119997638, 27.359997634, 27.359997635, 31.679997379, 31.67999738, 50.879992027, 50.879992028, 66.559982973, 80.639970829, 80.63997083, 80.639970832, 80.639970833, 87.039963981, 87.039963983, 87.039963984, 95.999952696, 95.999952697, 95.999952698, 95.999952699, 95.9999527, 95.999952701, 96.639951948, 96.639951949, 96.63995195, 96.639951951, 96.639951952, 96.639951953, 96.639951954, 96.639951955, 104.319943019, 104.31994302, 104.319943021, 104.319943022, 116.639928764, 116.639928767, 266.079715526, 278.079706122, 278.079706124, 278.079706125]
print(len(simtwo_data))

# %%
sequence_data = [1.44002501, 1.44058751, 2.88015001, 3.04010001, 3.68005001, 3.68063751, 5.12015001, 5.28033751, 5.28053751, 5.28067501, 6.24031251, 6.24037501, 7.04022501, 7.04041251, 7.36065001, 8.16026251, 8.48047501, 9.28028751, 10.40077501, 11.20026251, 11.36041251, 11.52065001, 11.68055001, 12.16021251, 12.16057501, 12.32043751, 12.80037501, 12.96065001, 14.40050001, 14.40056251, 14.72066251, 15.04056251, 15.20033751, 15.20053751, 16.16028751, 16.80077501, 19.04072501, 20.48052501, 20.48073751, 20.64082501, 21.28052501, 22.40087501, 23.68093751, 25.12076251, 30.72055001, 31.04090001, 32.00072501, 38.56116251, 48.80096251, 58.08142501]
print(len(sequence_data))

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(10, 4))
plt.plot(simtwo_data, range(1, len(simtwo_data) + 1), marker="o", label='Simtwo')
plt.plot(sequence_data, range(1, len(sequence_data) + 1), marker="o", label='SeQUeNCe')
plt.xlabel("Simulation Time (ms)", size='14')
plt.ylabel("Aggregated Number of\nEntangled Memory", size='14')
plt.legend(fontsize='14', loc='lower right')
plt.savefig('ed_demo_comp.png')
plt.show()
